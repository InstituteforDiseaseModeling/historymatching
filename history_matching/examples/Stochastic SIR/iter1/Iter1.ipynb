# %% [markdown]
# # Iteration 1 of History Matching for a stochastic SIR model
#
# In this example, we assume that prevalence has been observed at two distinct times.  For iteration 2, we will "cut" down parameter space using only the observation of prevalence at the SECOND time point.

# %%
# First load some libraries, including History Matching
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pyDOE import lhs
from wand.image import Image as WImage
from IPython.display import display

from history_matching import HistoryMatching, HistoryMatchingCut, quick_read, Basis
from history_matching.examples.sir import SIR
# Out:
# /home/clorton/src/hm-phylo-test/.phylo/lib/python3.8/site-packages/skcuda/cublas.py:284: UserWarning: creating CUBLAS context to get version number
#   warnings.warn('creating CUBLAS context to get version number')

# %% [markdown]
# ### Configure parameters and data for History Matching
# Note: This is (and must be) the same as on iteration 0.  Ordinarily I would read from file.

# %%
# WORK_DIR = Path(__file__).parent.absolute()     # version for script
WORK_DIR = Path.cwd().absolute()                # version for notebook
iteration = int(re.search(r'iter(\d+)', WORK_DIR.parts[-1]).group(1)) # Index of the current iteration

print(f"WORK_DIR is '{WORK_DIR}'")
print(f"Current iteration is {iteration}")
# Out:
# WORK_DIR is '/home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1'
# Current iteration is 1

# %%
# The implausibility threshold determines how willing we are to retain regions
# of parameter space that are inconsistent with the underlying data. A higher
# threshold is more risk averse in that potentially good regions are less likely
# to be rejected, however it will take more iterations/simulations to achieve results.
implausibility_threshold = 3
n_samples_per_iter = 100 # Number of simulations to conduct on this iteration
n_samples_to_generate_for_next_iter = 100 # Number of simulations to conduct on this iteration
training_fraction = 0.75 # Fraction of simulations to use as training
discrepancy_std = 3 # Accounts for uncertainty w.r.t model structure

# %%
# Observed data
observations = pd.DataFrame({
    'Times': [3, 15],
    'Prevalence': [15, 40],
    'Stdev': [4, 2.3],
})
display(observations)

# For this first iteration, we're going to make one "cut" using the first observation, but 
# you can separately do multiple "cuts" per iteration using several obervations (separately)
# We'll need a name for this cut and the desired results
desired_result_idx = 1 # Pick observation 0 or 1 [integers]
cut_name = 'Prevalence_Meas_%d'%desired_result_idx # No spaces or strange characters!

desired_result_idx = 1 # Use the SECOND measurement
desired_result = observations.iloc[desired_result_idx]['Prevalence']
desired_result_var = observations.iloc[desired_result_idx]['Stdev']**2
# Out:
#    Times  Prevalence  Stdev
# 0      3          15    4.0
# 1     15          40    2.3

# %%
# Here we define the parameter names and ranges
param_info = pd.DataFrame({
    'Name':['Beta', 'Gamma'],
    'Min':[1e-6, 1e-6],
    'Max':[0.01, 0.5]
}).set_index('Name')
params = param_info.index.values
n_params = param_info.shape[0] # We'll use this one place later
display(param_info)
# Out:
#             Min   Max
# Name
# Beta   0.000001  0.01
# Gamma  0.000001  0.50

# %% [markdown]
# ### Load samples selected on the previous iteration and run simulations for this iteration. Also process and plot results

# %%
# For the first iteration, the samples are random.  We'll use Latin Hypercube Sampling
# to make the samples more uniformly random.
# samples should be a pandas data frame, and must have an index named 'Sample_Id'
samples = pd.read_csv( WORK_DIR.parent / f"iter{iteration-1}" / f"Candidates_for_iter{iteration}.csv").loc[:n_samples_per_iter]
samples.index.name = 'Sample_Id'

# Plot the samples
f, ax = plt.subplots(figsize=(6,6))
ax.scatter(x=samples[param_info.index.values[0]], y=samples[param_info.index.values[1]])
ax.set_xlim([param_info['Min'][0], param_info['Max'][0]])
ax.set_ylim([param_info['Min'][1], param_info['Max'][1]])
ax.set_xlabel(param_info.index.values[0])
ax.set_ylabel(param_info.index.values[1])
# Out:
# Text(0, 0.5, 'Gamma')

# %%
# Run the simulations specified by the samples and plot the results

f = plt.figure(figsize=(16,10))
sim_results = []
for idx, sample in samples.iterrows():
    z = SIR(beta=sample['Beta'], gamma=sample['Gamma'])
    T,_,P = z.sim() # Run the simulation
    prevalence = [p[1] for p in P] # Analyze the simulation to get the prevalence
    
    # Because we used SSA, the time vector T does not contain the prevalence at the 
    # exact observation time, t_obs.  Let's find the first measurement after t_obs
    # Here I'm getting both observations, but we really only need one
    for i, t_obs in enumerate(observations['Times']):
        value = next((p[1] for t,p in zip(T,P) if t>t_obs), None)
        if not value:
            value = P[-1][1]
        sim_results.append([idx, i, t_obs, value])
    
    # Plot
    plt.plot(T,prevalence)

# Convert sim_results into a pandas DataFrame
sim_results = pd.DataFrame(sim_results, columns=['Sample_Id', 'ObsIdx', 'ObsTime', 'Prevalence'])

# Simulation results will ultimately need a 'Sample_Id' and 'Sim_Id'
# The Sample_Id corresponds to the index in the samples dataframe above
# You can do more than one replicate of each sample, in which case you'd
# end up wiht more than one Sim_Id per Sample_Id.  We're not doing that here,
# so we can basically set Sim_Id to anything.
sim_results['Sim_Id'] = sim_results['Sample_Id']
    
# Plot the observations over the realized trajectories
for i,obs in observations.iterrows():
    plt.plot(obs['Times'], obs['Prevalence'], 'ko')
    plt.plot(
        [obs['Times'],obs['Times']], 
        [obs['Prevalence']-2*obs['Stdev'],obs['Prevalence']+2*obs['Stdev']],
        'k-')

# %%
# sim_results contains the simulated values at both observation times, but for this iteration
# we only want to use the SECOND one (ObsIdx == 1).
# Also note that results must be a Series with index containing 'Sample_Id' and 'Sim_Id'
results = sim_results \
    .query('ObsIdx==@desired_result_idx')[['Sample_Id', 'Sim_Id', 'Prevalence']] \
    .set_index(['Sample_Id', 'Sim_Id'])['Prevalence']
display(results.tail())
# Out:
# Sample_Id  Sim_Id
# 96         96         3.0
# 97         97         0.0
# 98         98         0.0
# 99         99         4.5
# 100        100       33.5
# Name: Prevalence, dtype: float64

# %% [markdown]
# ## Now begins History Matching!
# ### First step is to emulate the selected simulation output

# %%
# Finally we get to do some History Matching!

# Begin by creating an instance of the HistoryMatching class
hm = HistoryMatching(
    cut_name = cut_name,
    param_info = param_info,
    inputs = samples,
    results = results,
    desired_result = desired_result,
    desired_result_var = desired_result_var,
    iteration = iteration,
    implausibility_threshold = implausibility_threshold,
    discrepancy_var = discrepancy_std**2,
    training_fraction = training_fraction,
    iterdir = WORK_DIR
)
hm.save() # Save to disk
# Out:
# 09/06 10:52:52 - history_matching.HistoryMatching - INFO     - Welcome to IDM History Matching!
# 09/06 10:52:52 - history_matching.HistoryMatching - INFO     - Found 101 unique parameter configurations, each of which is repeated 1 time(s).
# 09/06 10:52:52 - history_matching.HistoryMatching - INFO     - --> Training with 76 unique parameter configurations (76 simulations including replicates)
# 09/06 10:52:52 - history_matching.HistoryMatching - INFO     - --> Testing  with 25 unique parameter configurations (25 simulations including replicates)

# %%
# Now we begin the process of emulating the simulation output
# This process contains two steps.  The first step is to fit a deterministic model, here
# we use a generalized linear model (GLM).  The glm will attempt to model the output (prevalence 
# at the first observation) as a function of some inputs.  Those inputs need not be the model
# parameters directly!  The inputs could be anything from a constant intercept up to third or higher
# order interaction terms between parameters.  The following Basis instance builds out the GLM input
# parameters from the overall simulation input parameters.
#
# Some strategy is required when choosing these.  If you know which parameters matter, there's a way
# to directly specify those parameters.  Alternatively, if you have no idea, you can initially include 
# an intercept, first, second, and maybe also third order interaction terms.  The Basis class has a 
# built-in penalized regression that throws away unneeded terms (basis vectors).
# The second step of emulation, as demonstrated here, fits a GPR to the redisual error between the 
# simulated outputs and the GLM estimates.  If the GLM fits really well, the residual is mostly noise and
# the GPR has a hard time fitting / isn't very informative.  I actually prefer to weaken the GLM enough
# to leave plenty of residual signal for the GPR.  Here, I use only first-order (beta and gamma) terms.
basis_glm = Basis.polynomial_basis(
    params = param_info.index.values,
    intercept = True,
    first_order = True,
    second_order = False,
    third_order = False,
    param_info = param_info)

# %%
# Now fit the glm and plot

### GLM ###############################################################
print("="*80, "\nGeneralized Linear Modeling\n", "="*80)
#######################################################################
f = hm.glm(
    basis = basis_glm,
    family = 'Gaussian',
    force_optimize_glm = True,
    glm_fit_maxiter = 100000,
    plot = True, #force_optimize_glm,
    plot_data = True
)
# Out:
# ================================================================================
# Generalized Linear Modeling
#  ================================================================================
# 09/06 10:52:52 - history_matching.glm - INFO     - Using Gaussian family
# 09/06 10:52:52 - history_matching.HistoryMatching - INFO     - Fitting the GLM
# 09/06 10:52:52 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:52 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:52 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:52 - history_matching.glm - INFO     - Fitting the model, please wait ...
# 09/06 10:52:52 - history_matching.glm - INFO     -                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             Sim_Result   No. Observations:                   76
# Model:                            GLM   Df Residuals:                       73
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                          222.78
# Method:                          IRLS   Log-Likelihood:                -311.74
# Date:                Tue, 06 Sep 2022   Deviance:                       16263.
# Time:                        10:52:52   Pearson chi2:                 1.63e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):             0.6486
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     35.7833      3.930      9.106      0.000      28.081      43.485
# Beta          31.0390      9.794      3.169      0.002      11.842      50.236
# Gamma        -58.6291      6.598     -8.886      0.000     -71.561     -45.697
# ==============================================================================
# 09/06 10:52:52 - history_matching.glm - INFO     - AIC:       629.4866242502785
# 09/06 10:52:52 - history_matching.glm - INFO     - BIC (LLF): 636.4788242711375
# 09/06 10:52:52 - history_matching.HistoryMatching - INFO     - Evaluating training and test data
# 09/06 10:52:52 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:52 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:52 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:52 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:52 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:52 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:53 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:53 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:53 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:53 - history_matching.basis - INFO     - Basis: Unable to scale Yglm

# %%
for file in (Path(hm.glmdir) / "PairwiseResults").glob("*.pdf"):
    img = WImage(filename=file)
    print(file)
    display(img)
# Out:
# /home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Cuts/Prevalence_Meas_1/GLM/PairwiseResults/Beta-Gamma.pdf
# <wand.image.Image: fb0041b 'PDF' (1152x864)>

# %%
# Results get saved to disk, so load and display:
filename = Path(hm.glmdir) / "GLM Predicted vs Actual.pdf"
img = WImage(filename=filename)
print(file)
display(img)
# Out:
# /home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Cuts/Prevalence_Meas_1/GLM/PairwiseResults/Beta-Gamma.pdf
# <wand.image.Image: a4d7e53 'PDF' (1152x864)>

# %%
basis_gpr = Basis.polynomial_basis(
    params=param_info.index.values, 
    intercept = False, 
    first_order=True, 
    param_info=param_info)

# %%
### GPR ###############################################################
print("="*80, "\nGaussian Process Regression\n", "="*80)
#######################################################################
hm.gpr(
    basis = basis_gpr,
    force_optimize_gpr = True,

    sigma2_f_guess = 0.6,
    sigma2_f_bounds = (0.1, 1000),
    sigma2_n_guess =  2.0,
    sigma2_n_bounds = (0.01, 100),

    #lengthscale_guess = [0.09844299, 0.1256657, 0.0976875, 0.09889085, 0.1051974, 0.0950809, 0.10032171, 0.10599185, 0.10627393, 0.09950996, 0.09445544, 0.10285915, 0.10007409, 0.09847433, 0.08963389, 0.10205652, 0.09360044, 0.1024141, 0.09786228, 0.10247492, 0.09852253, 0.09632744, 0.09997534, 0.10767302, 0.10095249, 0.09941825, 0.10214923, 0.10221497, 0.09734157, 0.09093285, 0.10780673, 0.09881377, 0.10597152],
    lengthscale_guess = 0.25,
    lengthscale_bounds = (0.01, 100),

    optimize_sigma2_n = True,
    log_transform = False,

    verbose = True,
    optimizer_options = {
        'eps': 5e-3,
        'disp': True,
        'maxiter': 15000,
        'ftol': 2 * np.finfo(float).eps,
        'gtol': 2 * np.finfo(float).eps,
    },
    plot = True, #force_optimize_gpr,
    plot_data = True
)
# Out:
# ================================================================================
# Gaussian Process Regression
#  ================================================================================
# 09/06 10:52:54 - history_matching.gpr - INFO     - Autoinit GPU device name:NVIDIA GeForce GTX 1650 Ti with Max-Q Design
# 09/06 10:52:54 - history_matching.HistoryMatching - INFO     - Backing up gpr model to /home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Cuts/Prevalence_Meas_1/GPR/model_2022_09_06_10_52_54.json
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Yerr
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Yerr_normalized
# 09/06 10:52:54 - history_matching.HistoryMatching - INFO     - Fitting the GPR
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale index
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Yerr
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Yerr_normalized
# 09/06 10:52:54 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Index
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.12337D+02    |proj g|=  4.35247D+00
#
# At iterate    1    f=  2.70457D+01    |proj g|=  9.99769D+01
#   ys=-1.156E+02  -gs= 4.614E+01 BFGS update SKIPPED
#
# At iterate    2    f=  2.27393D+01    |proj g|=  8.91823D-01
#
# At iterate    3    f=  1.65599D+01    |proj g|=  6.96691D-01
#
# At iterate    4    f=  1.16737D+01    |proj g|=  4.62088D-01
#
# At iterate    5    f=  9.68333D+00    |proj g|=  6.29331D+01
#
# At iterate    6    f=  9.56311D+00    |proj g|=  9.11409D+00
#
# At iterate    7    f=  9.55451D+00    |proj g|=  1.14601D+00
#
# At iterate    8    f=  9.55451D+00    |proj g|=  1.14601D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      8     34     16     1     0   1.146D+00   9.555D+00
#   F =   9.5545116083049209
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yerr
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yerr_normalized
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Index
# 09/06 10:52:55 - history_matching.HistoryMatching - INFO     - GPR evaluating training data
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yerr
# 09/06 10:52:55 - history_matching.HistoryMatching - INFO     - GPR evaluating test data
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yerr
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yerr
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Mean_Err
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Mean_Estimate
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Var_Err_Predictive
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Var_Err_Latent
# 09/06 10:52:55 - history_matching.basis - INFO     - Basis: Unable to scale Yerr_normalized
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#       fun: 9.55451160830492
#  hess_inv: <4x4 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.24173209, -1.14600988,  0.76572185, -0.19862874])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 32
#       nit: 8
#      njev: 32
#    status: 0
#   success: True
#         x: array([4.71569124, 0.04836056, 0.03459634, 0.08430119])

# %%
# Results get saved to disk, so load and display:
for file in (Path(hm.gprdir) / "PairwiseResults").glob("*.pdf"):
    img = WImage(filename=file)
    print(file)
    display(img)
# Out:
# /home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Cuts/Prevalence_Meas_1/GPR/PairwiseResults/Beta-Gamma.pdf
# <wand.image.Image: cae8341 'PDF' (1152x864)>

# %%
# Results get saved to disk, so load and display:
filename = Path(hm.gprdir) / "gpr.pdf"
img = WImage(filename=filename)
print(file)
display(img)
# Out:
# /home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Cuts/Prevalence_Meas_1/GPR/PairwiseResults/Beta-Gamma.pdf
# <wand.image.Image: edfa976 'PDF' (1152x864)>

# %% [markdown]
# ## Check the fit of the overall (GLM+GPR) emulator

# %%
hm.plot()
# Results get saved to disk, so load and display:
filename = Path(hm.cutdir) / "emulation.pdf"
img = WImage(filename=filename)
print(file)
display(img)
# Out:
# /home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Cuts/Prevalence_Meas_1/GPR/PairwiseResults/Beta-Gamma.pdf
# <wand.image.Image: 13e4a6e 'PDF' (1152x864)>

# %% [markdown]
# ### Now use the emulator to calculate "implausibility."  New simulations will not be commissioned on future iterations where implasibility is high.

# %%
### Implausibility ############################################################
print("="*80, "\nImplausibility\n", "="*80)
###############################################################################
hm.calc_and_plot_implausibility(
    plot = True,
    do_plot_data = True,
    plot_data_highlight = pd.DataFrame() #hm.test_data.loc['prime.000049']
) 
    #plot_data_highlight=pd.DataFrame() # plot_data_highlight=hm.training_data.loc['prime.000049']

hm.training_data.to_excel( WORK_DIR / "Cuts" / cut_name / "train_data.xlsx" )
hm.test_data.to_excel( WORK_DIR / "Cuts" / cut_name / "test_data.xlsx" )

print('Good')
# Out:
# ================================================================================
# Implausibility
#  ================================================================================
# Good

# %%
# Results get saved to disk, so load and display:
for file in (Path(hm.combineddir) / "PairwiseResults").glob("*/*.pdf"):
    img = WImage(filename=file)
    print(file)
    display(img)
# Out:
# /home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Cuts/Prevalence_Meas_1/Implausibility/PairwiseResults/Test/Beta-Gamma.pdf
# <wand.image.Image: aaa2372 'PDF' (1152x864)>
# /home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Cuts/Prevalence_Meas_1/Implausibility/PairwiseResults/Train/Beta-Gamma.pdf
# <wand.image.Image: 90c41a7 'PDF' (1152x864)>

# %%
# Results get saved to disk, so load and display:
for file in Path(hm.combineddir).glob("*.pdf"):
    img = WImage(filename=file)
    print(file)
    display(img)
# Out:
# /home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Cuts/Prevalence_Meas_1/Implausibility/implausibility.pdf
# <wand.image.Image: 8090826 'PDF' (1152x864)>

# %% [markdown]
# ## Select samples for the next iteration
# Now that the emulators are fit, it's time to select samples for the next iteration.
# Here we use a class called HistoryMatchingCut.  It's job is to conduct rejection sampling in order to find n_samples_to_generate_for_next_iter new samples that are not implausible with respect to the emulation on this wave or any previous wave.  Resulting samples are saved to disk, so we'll load them in just to make a plot.

# %%
### Cut #######################################################################
print("="*80, "\nCut\n", "="*80)
###############################################################################
# History Matching!
hmc = HistoryMatchingCut(
    cut_folder = 'Cuts',
    iteration = int(re.search(r'iter(\d+)', WORK_DIR.parts[-1]).group(1)),
    iterdir_parent = WORK_DIR.parent
)

(_, rejected_percent) = hmc.cut(num_desired_candidates=n_samples_to_generate_for_next_iter, constraint = None)
# Out:
# ================================================================================
# Cut
#  ================================================================================
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - Reading iteration 1 cut Prevalence_Meas_1
# 09/06 10:52:58 - history_matching.HistoryMatching - INFO     - Welcome to IDM History Matching!
# 09/06 10:52:58 - history_matching.HistoryMatching - INFO     - Found 101 unique parameter configurations, each of which is repeated 1 time(s).
# 09/06 10:52:58 - history_matching.HistoryMatching - INFO     - --> Training with 76 unique parameter configurations (76 simulations including replicates)
# 09/06 10:52:58 - history_matching.HistoryMatching - INFO     - --> Testing  with 25 unique parameter configurations (25 simulations including replicates)
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - 	 Desired Result: 40
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - 	 Desired Result Var: 5.289999999999999
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - 	 Discrepancy Var: 9
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - 	 Imp Thresh: 3
# 09/06 10:52:58 - history_matching.glm - INFO     - Using Gaussian family
# 09/06 10:52:58 - history_matching.glm - INFO     -                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             Sim_Result   No. Observations:                   76
# Model:                            GLM   Df Residuals:                       73
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                          222.78
# Method:                          IRLS   Log-Likelihood:                -311.74
# Date:                Tue, 06 Sep 2022   Deviance:                       16263.
# Time:                        10:52:58   Pearson chi2:                 1.63e+04
# No. Iterations:                     3   Pseudo R-squ. (CS):             0.6486
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     35.7833      3.930      9.106      0.000      28.081      43.485
# Beta          31.0390      9.794      3.169      0.002      11.842      50.236
# Gamma        -58.6291      6.598     -8.886      0.000     -71.561     -45.697
# ==============================================================================
# 09/06 10:52:58 - history_matching.glm - INFO     - AIC:       629.4866242502785
# 09/06 10:52:58 - history_matching.glm - INFO     - BIC (LLF): 636.4788242711375
# 09/06 10:52:58 - history_matching.gpr - INFO     - Autoinit GPU device name:NVIDIA GeForce GTX 1650 Ti with Max-Q Design
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Yerr
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Mean_Err
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Mean_Estimate
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Var_Err_Predictive
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Var_Err_Latent
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Yerr_normalized
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - Reading iteration 0 cut Prevalence_Meas_0
# 09/06 10:52:58 - history_matching.HistoryMatching - INFO     - Welcome to IDM History Matching!
# 09/06 10:52:58 - history_matching.HistoryMatching - INFO     - Found 100 unique parameter configurations, each of which is repeated 1 time(s).
# 09/06 10:52:58 - history_matching.HistoryMatching - INFO     - --> Training with 75 unique parameter configurations (75 simulations including replicates)
# 09/06 10:52:58 - history_matching.HistoryMatching - INFO     - --> Testing  with 25 unique parameter configurations (25 simulations including replicates)
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - 	 Desired Result: 15
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - 	 Desired Result Var: 16
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - 	 Discrepancy Var: 9
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - 	 Imp Thresh: 3
# 09/06 10:52:58 - history_matching.glm - INFO     - Using Gaussian family
# 09/06 10:52:58 - history_matching.glm - INFO     -                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             Sim_Result   No. Observations:                   75
# Model:                            GLM   Df Residuals:                       72
# Model Family:                Gaussian   Df Model:                            2
# Link Function:               identity   Scale:                          72.396
# Method:                          IRLS   Log-Likelihood:                -265.47
# Date:                Tue, 06 Sep 2022   Deviance:                       5212.5
# Time:                        10:52:58   Pearson chi2:                 5.21e+03
# No. Iterations:                     3   Pseudo R-squ. (CS):             0.9971
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.9035      2.389      3.727      0.000       4.221      13.586
# Beta          71.8252      3.540     20.289      0.000      64.887      78.764
# Gamma        -32.2095      3.442     -9.357      0.000     -38.956     -25.463
# ==============================================================================
# 09/06 10:52:58 - history_matching.glm - INFO     - AIC:       536.9402840586413
# 09/06 10:52:58 - history_matching.glm - INFO     - BIC (LLF): 543.8927483992502
# 09/06 10:52:58 - history_matching.gpr - INFO     - Autoinit GPU device name:NVIDIA GeForce GTX 1650 Ti with Max-Q Design
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Id
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Sample_Orig
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Sim_Result
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Yerr
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Mean_Err
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Mean_Estimate
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Var_Err_Predictive
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Var_Err_Latent
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Yerr_normalized
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - --------------------------------------------------------------------------------
# 09/06 10:52:58 - history_matching.HistoryMatchingCut - INFO     - Performing cut: iteration 1, cut Prevalence_Meas_1
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Implausible
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Implausible
# 09/06 10:52:58 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:59 - history_matching.HistoryMatchingCut - INFO     - Performing cut: iteration 0, cut Prevalence_Meas_0
# 09/06 10:52:59 - history_matching.basis - INFO     - Basis: Unable to scale Implausible
# 09/06 10:52:59 - history_matching.basis - INFO     - Basis: Unable to scale Implausible
# 09/06 10:52:59 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:59 - history_matching.HistoryMatchingCut - INFO     - Plausible candidates: New =12, Tot =12
# 09/06 10:52:59 - history_matching.HistoryMatchingCut - INFO     - --------------------------------------------------------------------------------
# 09/06 10:52:59 - history_matching.HistoryMatchingCut - INFO     - Performing cut: iteration 1, cut Prevalence_Meas_1
# 09/06 10:52:59 - history_matching.basis - INFO     - Basis: Unable to scale Implausible
# 09/06 10:52:59 - history_matching.basis - INFO     - Basis: Unable to scale Implausible
# 09/06 10:52:59 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:59 - history_matching.HistoryMatchingCut - INFO     - Performing cut: iteration 0, cut Prevalence_Meas_0
# 09/06 10:52:59 - history_matching.basis - INFO     - Basis: Unable to scale Implausible
# 09/06 10:52:59 - history_matching.basis - INFO     - Basis: Unable to scale Implausible
# 09/06 10:52:59 - history_matching.basis - INFO     - Basis: Unable to scale Yglm
# 09/06 10:52:59 - history_matching.HistoryMatchingCut - INFO     - Plausible candidates: New =96, Tot =108
# 09/06 10:52:59 - history_matching.HistoryMatchingCut - INFO     - Saving to:/home/clorton/src/hm-phylo-test/history_matching/history_matching/examples/Stochastic SIR/iter1/Candidates_for_iter2.hd5
# 09/06 10:52:59 - history_matching.HistoryMatchingCut - INFO     - Rejected 88.6% [838 / 946]

# %%
# Samples for the next iteration are saved to file, in this case it's "Candidates_for_iter1.csv"
# Just to see what they look like, we'll read that file and plot the samples
# Notice how the entire bottom right of the paramter space is empty?  Those points were rejected!

samples = pd.read_csv(f"Candidates_for_iter{iteration+1}.csv")

f, ax = plt.subplots(figsize=(6,6))
ax.scatter(x=samples[param_info.index.values[0]], y=samples[param_info.index.values[1]])
ax.set_xlim([param_info['Min'][0], param_info['Max'][0]])
ax.set_ylim([param_info['Min'][1], param_info['Max'][1]])
ax.set_xlabel(param_info.index.values[0])
ax.set_ylabel(param_info.index.values[1]);

# %% [markdown]
# # Now move into the next directory to continue with the next iteration of this example!
